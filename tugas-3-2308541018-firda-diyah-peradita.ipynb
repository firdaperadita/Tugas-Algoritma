# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
tinggi = float(input("tinggi anda adalah"))
if tinggi >= 152:
    print(" anda termasuk pendek")
    print(" maka olahraga lagi!!!")
# Out:
# tinggi anda adalah 152
#  anda termasuk pendek
#  maka olahraga lagi!!!

# %%
nilai = float(input("nilai anda adalah"))
if nilai < 80 and nilai >= 70:
    print("anda mendapat nilai B")
    print("tingkatkan prestasimu!")
# Out:
# nilai anda adalah 78
# anda mendapat nilai B
# tingkatkan prestasimu!

# %%
a = 1
while a < 6:
    print("angka " + str(a)+ " merupakan bilangan prima")
    a +=2
# Out:
# angka 1 merupakan bilangan prima
# angka 3 merupakan bilangan prima
# angka 5 merupakan bilangan prima

# %%
berat = float(input("berapakah berat anda?"))
kg_atau_ton = input("beratnya dakam kg atau ton?")
if kg_atau_ton.upper() == 'KG':
    berat = berat*0.0011
    print("berat anda adalah " + str(berat) + " ton")
elif kg_atau_ton.upper() == "TON":
    berat = berat/0.0011
    print(f"berat anda adalah {berat} kg")
# Out:
# berapakah berat anda? 50
# beratnya dakam kg atau ton? kg
# berat anda adalah 0.055 ton
