# %%
print('Marii membuat program yang memuat dua titik dengan 1 gradien dan satu titik yang diewati dan persamaan ax + by = c')

import numpy as np
import matplotlib.pyplot as plt

#masukkan koordinat untuk garis pertama dan garis kedua
f_18 = float(input("Nilai titik x pertama dari garis pertama yaitu: "))
i_18 = float(input("Nilai titik y pertama dari garis pertama yaitu: "))
r_18 = float(input("Nilai titik x kedua dari garis pertama yaitu: "))
d_18 = float(input("Nilai titik y kedua dari garis pertama yaitu: "))

e_18 = float(input("Nilai titik x pertama dari garis kedua adalah "))
b_18 = float(input("Nilai titik y pertama dari garis kedua adalah "))
g_18 = float(input("Nilai titik x kedua dari garis kedua adalah "))
h_18 = float(input("Nilai titik y kedua dari garis kedua adalah "))

#menentukan gardien untuk kedua garis
m1_18 = (d_18 - i_18)/(r_18 - f_18) #gradien garis pertama
m2_18 = (h_18 - b_18)/(g_18 - e_18) #gradien garis kedua

print(f'gradien garis pertama adalah {m1_18}')
print(f'gradien garis kedua adalah {m2_18}')
pers1_18 = print(f'jadi persamaan garis pertama adalah c= {m1_18}x + {(m1_18*f_18)*-1} ')
pers2_18 = print(f'dan persamaan garis kedua adalah c= {m2_18}x + {(m1_18*f_18)*-1} ')

c1_18 = -m_1*f_18+i_18 # Titik potong garis pertama pada sumbu y pertama
c2_18 = -m_2*e_18+b_18 # titik potong garis kedua pada sumbu y kedua

    
tp_x_18 = (-m2_18*e_18+b_18+m1_18*f_18-i_18)/(m1_18-m2_18)
tp_y_18 = m1_18*(tp_x-f_18)+i_18
print("Titik potong yang dimiliki kedua garis adalah ({},{})".format(tp_x_18,tp_y_18))
    
x=np.linspace(tp_x_18-5,tp_x_18+5,100)
plt.plot(x,m1_18*(x-f_18)+i_18,color='brown')
plt.plot(x,m2_18*(x-e_18)+b_18,color='pink')
plt.plot(tp_x_18,tp_y_18,color="black",marker="o",markersize=4)
plt.axvline(x=0,color='grey')
plt.axhline(y=0,color='grey')
plt.title("gambar persamaan garis saling berpotongan")
plt.legend(loc='best')
plt.grid(True)
plt.show()
# Out:
# Marii membuat program yang memuat dua titik dengan 1 gradien dan satu titik yang diewati dan persamaan ax + by = c
# Nilai titik x pertama dari garis pertama yaitu:  8
# Nilai titik y pertama dari garis pertama yaitu:  7
# Nilai titik x kedua dari garis pertama yaitu:  10
# Nilai titik y kedua dari garis pertama yaitu:  9
# Nilai titik x pertama dari garis kedua adalah  8
# Nilai titik y pertama dari garis kedua adalah  8
# Nilai titik x kedua dari garis kedua adalah  10
# Nilai titik y kedua dari garis kedua adalah  9
# gradien garis pertama adalah 1.0
# gradien garis kedua adalah 0.5
# jadi persamaan garis pertama adalah c= 1.0x + -8.0
# dan persamaan garis kedua adalah c= 0.5x + -8.0
# Titik potong yang dimiliki kedua garis adalah (10.0,9.0)
