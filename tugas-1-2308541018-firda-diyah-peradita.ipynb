# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
nama = input("siapa nama anda?")
kegiatan = input('apa yang kamu lakukan akhir akhir ini, ' + nama +"?")
print("semoga "+ kegiatan +" menyenangkan ya," + nama + "!!!")
# Out:
# siapa nama anda? firda
# apa yang kamu lakukan akhir akhir ini, firda? mejadi panitia GC 2024
# semoga mejadi panitia GC 2024 menyenangkan ya,firda!!!

# %%
a = 1
while a < 6:
    print("angka " + str(a)+" merupakan bilangan prima")
    a += 2
# Out:
# angka 1 merupakan bilangan prima
# angka 3 merupakan bilangan prima
# angka 5 merupakan bilangan prima

# %%
nama_depan = 'firda'
nama_tengah = ' '
nama_belakang = 'peradita'
print(nama_depan + nama_tengah + nama_belakang)
# Out:
# firda peradita

# %%
print(3+5)
print(3-5)
print(6/2)
print(6//2)
print(6%2)
print(3**4)
x=3
x+=6
print(x)
x-= 4
print(x)
x*=5
print(x)
# Out:
# 8
# -2
# 3.0
# 3
# 0
# 81
# 9
# 5
# 25

# %%
tinggi = float(input("tinggi anda adalah"))
if tinggi >= 152:
    print("anda termasuk pendek")
    print("maka olahraga lagi!")
# Out:
# tinggi anda adalah 152
# anda termasuk pendek
# maka olahraga lagi!

# %%
def create_triangle(height):
    for i in range(1, height + 1):
        print(" " * (height - i) + "*" * (2 * i - 1))

create_triangle(6)
# Out:
#      *
#     ***
#    *****
#   *******
#  *********
# ***********

# %%
def inverted_triangle(height):
    for i in range(height, 0, -1):
        print(" " * (height - i) + "*" * (2 * i - 1))

inverted_triangle(6)
# Out:
# ***********
#  *********
#   *******
#    *****
#     ***
#      *

# %%
def generate_pascal_triangle(n):
    triangle = []
    for line in range(1, n + 1):
        row = []
        for i in range(line):
            if i == 0 or i == line - 1:
                row.append(1)
            else:
                row.append(triangle[line - 2][i - 1] + triangle[line - 2][i])
        triangle.append(row)
    return triangle

def print_pascal_triangle(triangle):
    max_width = len(" ".join(map(str, triangle[-1])))
    for row in triangle:
        row_str = " ".join(map(str, row))
        print(row_str.center(max_width))

pascal_triangle = generate_pascal_triangle(4)
print_pascal_triangle(pascal_triangle)
# Out:
#    1
#   1 1
#  1 2 1
# 1 3 3 1
